# %%
import pandas as pd

# %%
data = pd.read_csv("ecommerce.csv")
data.head()
# Out:
#    ID                Name  Age Gender         City             Country
# 0   0    Elizabeth Harris   42      F    Chungberg  Mismatched Country  \
# 1   1        Michele Best   72      M  Port Sergio               Egypt
# 2   2         Jake Taylor   -5      M   Evansmouth      Czech Republic
# 3   3  Christian Curry MD   64      M   Jensenfurt   Brunei Darussalam
# 4   4         Craig Jones   92      M   East Jerry   Wallis and Futuna
#
#          CreditCard                                        FullAddress
# 0  2227218447017949  75874 Chad Mountain Suite 588, West Robertches...  \
# 1  2556439104848944  4039 David Fords Apt. 678, Lake Christopherber...
# 2  2273966520760545  748 Mendez Ridges Apt. 994, Lake Jonathanton, ...
# 3  2238348117052863             735 Jones Mews, New Ginafurt, AR 99785
# 4  2225629684025639         95949 Jill Circle, Tuckerchester, VI 49522
#
#   UserSignUpDate UserLastPurchaseDate  ... UserLastLoginDate
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1500 non-null   int64
#  1   Name                   1500 non-null   object
#  2   Age                    1500 non-null   int64
#  3   Gender                 1500 non-null   object
#  4   City                   1500 non-null   object
#  5   Country                1500 non-null   object
#  6   CreditCard             1500 non-null   int64
#  7   FullAddress            1500 non-null   object
#  8   UserSignUpDate         1500 non-null   object
#  9   UserLastPurchaseDate   1500 non-null   object
#  10  UserStatus             1500 non-null   object
#  11  UserTotalPurchases     1500 non-null   int64
#  12  UserSegment            1500 non-null   object
#  13  UserLocation           1500 non-null   object
# ...

# %% [markdown]
# Transformations
#
# - FullAddress
# - UserSignUpDate --> Date
# - UserLastPurchaseDate --> Date
# - UserStatus
# - UserTotalPurchases
# - UserSegment

# %%
data["UserSegment"].unique()
# Out:
# array(['Frequent Shopper', 'High Value', 'Occasional Shopper'],
#       dtype=object)

# %%
data.loc[data["Country"]=="Mismatched Country"].count()
# Out:
# ID                       38
# Name                     38
# Age                      38
# Gender                   38
# City                     38
# Country                  38
# CreditCard               38
# FullAddress              38
# UserSignUpDate           38
# UserLastPurchaseDate     38
# UserStatus               38
# UserTotalPurchases       38
# UserSegment              38
# UserLocation             38
# UserSourceType           38
# UserLastLoginDate        38
# UserPurchaseFrequency    38
# Product Name              0
# Category                 38
# Subcategory              38
# Price                    38
# Date_Purchase            38
# Quantity                 38
# Rating                   38
# Comment                  38
# dtype: int64

# %%
data["age"]

# %% [markdown]
# ## Hypothèses

# %%
- Les valeurs négatives sont dues à des erreurs de frappe
- 8<age<13: usage des cartes de crédit des parents
- age<8 : ??
- age>100: ??
